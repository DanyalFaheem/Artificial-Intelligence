# %%
from copy import deepcopy                        
import random                                  
from math import exp                            
import numpy as np
board_size =0

def placeQueens(board):                          
    i = 0
    while (i < board_size):
        row = random.randint(0, board_size - 1)
        if (board[row][i] != "Q"):
            board[row][i] = "Q"
            i+=1

def getQueens(board):                            # This will get the positions of queens palced in the maze
    queen_positions = []                         
    for i in range(board_size):
        for j in range (board_size):
            if board[i][j] == "Q":
                temp = i,j
                queen_positions.append(temp)
    return queen_positions

def printBoard(board):                          
    for i in range(board_size):
        for j in range(board_size):
            print(board[i][j], end=' ')
        print()



def objective_function(board):    
    pass
    
    # This function will return the number of attacking queens
    # Step 1: Seeing if two queens are in same rows
    
    # Step 2 : Now we will check diagonals
    # There are a total of 4 diagonals
    
    # Top-Left Diagonal
    # Bottom-Right Diagonal
    # Bottom-Left Diagonal
    # Top-Right Diagonal
    
    return h

# %%
def hillClimbing(board): 
    pass
       # ------Steepest Ascend-------
       # --Getting the positions of queens
       # (here use the function defined to get the positions.)
        
       # --Getting number of atttacking queens
       # (Remember this is the heuristic value through the objective function that you)
       #  will define
       # this is the heuristic of the current state , h =17
    
        
       # --Exploring all possible combinations
       # (Remember you have to get all possible boards by moving the queen in one square in the same column )
       # You can have a separate function for this that returns list of boards.
    
      
       # --Returning the board with minimum number of attacking queens
       # (You will select the board that has min h [using objective function ])
      
       # --Returning the minimum number of attacking queens
       # (The h of the board you selected previously)
       
       # --Finding the optimal solution (i.e No attacking queens)
       # (use the above h to see if it reaches global maxima that is h==0)
       # global maxima  terminate 
       
       # (use the above h to see if it reaches local maxima that is h >= heuristic of current state , h=17)
       # return here as well
       # loal maxima
        
       # Keep the loop iterating
       # make the minimum board you selected your current board. 
                
def main():
    global board_size
    board_size = int(input("Enter the board size:"))
    
    rows , cols = (board_size,board_size)
    board = []                                       

    for i in range(rows):                         
        col = []
        for j in range(cols):                       
            col.append("*")                       
        board.append(col)
    
    placeQueens(board)
    printBoard(board)
    print( getQueens(board))
 
    
if __name__ == "__main__":
    main()
# Out:
# Enter the board size:8
# * * * * Q * * *
# * * * * * * Q *
# * * Q * * * * *
# * * * * * * * *
# Q * * Q * Q * *
# * * * * * * * *
# * * * * * * * Q
# * Q * * * * * *
# [(0, 4), (1, 6), (2, 2), (4, 0), (4, 3), (4, 5), (6, 7), (7, 1)]
